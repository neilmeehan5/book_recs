# %%
import pandas as pd
from sqlalchemy import create_engine
from mysecrets import user, password

engine = create_engine(f'postgresql://{user}:{password}@localhost:5432/book_recs')

# %%
pd.read_sql(
    """
    SELECT *
    FROM GOODREADS_BOOKS
    WHERE TITLE LIKE 'Slaughterhouse Five'
    """,
    engine
)
# Out:
#           isbn  text_reviews_count series country_code language_code  \
# 0          NaN                  13     []           US           eng
# 1   60735554.0                   6     []           US           eng
# 2          NaN                   1     []           US
# 3          NaN                  32     []           US           eng
# 4  844663662.0                 145     []           US           eng
# 5  710090049.0                   4     []           US           eng
# 6   60799161.0                  45     []           US
#
#          asin is_ebook  average_rating kindle_asin  \
# 0  B000FA5QZO     true            4.06  B003XVYLDU
# 1                false            4.06
# 2                false            4.06  B003XVYLDU
# 3                false            4.06
# 4                false            4.06  B003XVYLDU
# 5                false            4.06
# 6                false            4.06
#
#                                        similar_books  ... publication_month  \
# 0  ['91494', '22584', '92508', '243598', '12467',...  ...               1.0
# 1  ['91494', '22584', '92508', '243598', '12467',...  ...              11.0
# 2  ['91494', '22584', '92508', '243598', '12467',...  ...               NaN
# 3  ['91494', '22584', '92508', '243598', '12467',...  ...               NaN
# 4  ['91494', '22584', '92508', '243598', '12467',...  ...               NaN
# 5  ['91494', '22584', '92508', '243598', '12467',...  ...               NaN
# 6  ['91494', '22584', '92508', '243598', '12467',...  ...              11.0
#
#               edition_information publication_year  \
# 0                                           2001.0
# 1                                           2003.0
# 2                        Abridged              NaN
# 3  alt cover dell 8029 0440080290           1971.0
# 4                                              NaN
# 5            First Laurel Edition           1988.0
# 6                         Digital           2003.0
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/6308664-sl...
# 1  https://www.goodreads.com/book/show/3271073-sl...
# 2  https://www.goodreads.com/book/show/9618.Slaug...
# 3  https://www.goodreads.com/book/show/1074901.Sl...
# 4  https://www.goodreads.com/book/show/28131.Slau...
# 5  https://www.goodreads.com/book/show/13449084-s...
# 6  https://www.goodreads.com/book/show/9568528-sl...
#
#                                            image_url   book_id  ratings_count  \
# 0  https://images.gr-assets.com/books/1296250089m...   6308664            342
# 1  https://images.gr-assets.com/books/1433476592m...   3271073             55
# 2  https://images.gr-assets.com/books/1433478355m...      9618             19
# 3  https://images.gr-assets.com/books/1395584346m...   1074901            181
# 4  https://s.gr-assets.com/assets/nophoto/book/11...     28131           1187
# 5  https://images.gr-assets.com/books/1488747300m...  13449084             31
# 6  https://images.gr-assets.com/books/1355127851m...   9568528            155
#
#    work_id                title  title_without_series
# 0  1683562  Slaughterhouse Five   Slaughterhouse Five
# 1  1683562  Slaughterhouse Five   Slaughterhouse Five
# 2  1683562  Slaughterhouse Five   Slaughterhouse Five
# 3  1683562  Slaughterhouse Five   Slaughterhouse Five
# 4  1683562  Slaughterhouse Five   Slaughterhouse Five
# 5  1683562  Slaughterhouse Five   Slaughterhouse Five
# 6  1683562  Slaughterhouse Five   Slaughterhouse Five
#
# [7 rows x 27 columns]
